# %% [markdown]
# <a href="https://colab.research.google.com/github/trunfo4608/Python-Analise_Restaurante/blob/main/Proj_Analise_Dados_Fumantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
 sub_set = df.rename(
    columns={
        'total_bill':'TOTAL PAGO',
        'tip': 'GORJETA',
        'sex':'SEXO',
        'smoker':'FUMANTE',
        'day':'DIA SEMANA',
        'time':'PERIODO',
        'size':'QTDE PESSOAS'
    }
)

sub_set
# Out:
#      TOTAL PAGO  GORJETA    SEXO FUMANTE DIA SEMANA PERIODO  QTDE PESSOAS
# 0         16.99     1.01  Female      No        Sun  Dinner             2
# 1         10.34     1.66    Male      No        Sun  Dinner             3
# 2         21.01     3.50    Male      No        Sun  Dinner             3
# 3         23.68     3.31    Male      No        Sun  Dinner             2
# 4         24.59     3.61  Female      No        Sun  Dinner             4
# ..          ...      ...     ...     ...        ...     ...           ...
# 239       29.03     5.92    Male      No        Sat  Dinner             3
# 240       27.18     2.00  Female     Yes        Sat  Dinner             2
# 241       22.67     2.00    Male     Yes        Sat  Dinner             2
# 242       17.82     1.75    Male      No        Sat  Dinner             2
# 243       18.78     3.00  Female      No       Thur  Dinner             2
#
# [244 rows x 7 columns]

# %%
valores_periodo = sub_set['PERIODO'].unique()
valores_periodo
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
def mudaSexoNome(sexo):

  if sexo == 'Male':
    return 'Masculino'
  else:
    return 'Feminino'
pass


def mudaFumanteNome(fumante):

  if fumante == 'Yes':
    return 'Sim'
  else:
    return 'Nao'
pass

def mudaDiaSemanaNome(diaSemana):

  if diaSemana == 'Sun':
    return 'Dom'
  elif diaSemana == 'Mon':
    return 'Seg'
  elif diaSemana == 'Tue':
    return 'Ter'
  elif diaSemana == 'Wed':
    return 'Qua'
  elif diaSemana =='Thu':
    return 'Qui'
  elif diaSemana == 'Fri':
    return 'Sex'
  else:
    return 'Sab'
pass


def mudaPeriodoNome(periodo):

  if periodo == 'Dinner':
    return 'Jantar'
  else:
    return 'Almoco'
pass

# %%
sub_set
# Out:
#      TOTAL PAGO  GORJETA    SEXO FUMANTE DIA SEMANA PERIODO  QTDE PESSOAS
# 0         16.99     1.01  Female      No        Sun  Dinner             2
# 1         10.34     1.66    Male      No        Sun  Dinner             3
# 2         21.01     3.50    Male      No        Sun  Dinner             3
# 3         23.68     3.31    Male      No        Sun  Dinner             2
# 4         24.59     3.61  Female      No        Sun  Dinner             4
# ..          ...      ...     ...     ...        ...     ...           ...
# 239       29.03     5.92    Male      No        Sat  Dinner             3
# 240       27.18     2.00  Female     Yes        Sat  Dinner             2
# 241       22.67     2.00    Male     Yes        Sat  Dinner             2
# 242       17.82     1.75    Male      No        Sat  Dinner             2
# 243       18.78     3.00  Female      No       Thur  Dinner             2
#
# [244 rows x 7 columns]

# %%
sub_set['SEXO'] = sub_set.apply(lambda row: mudaSexoNome(row['SEXO']),axis=1)
sub_set['FUMANTE'] = sub_set.apply(lambda row: mudaFumanteNome(row['FUMANTE']),axis=1)
sub_set['DIA SEMANA'] = sub_set.apply(lambda row: mudaDiaSemanaNome(row['DIA SEMANA']),axis=1)
sub_set['PERIODO'] = sub_set.apply(lambda row: mudaPeriodoNome(row['PERIODO']),axis=1)


sub_set
# Out:
#      TOTAL PAGO  GORJETA       SEXO FUMANTE DIA SEMANA PERIODO  QTDE PESSOAS
# 0         16.99     1.01   Feminino     Nao        Dom  Jantar             2
# 1         10.34     1.66  Masculino     Nao        Dom  Jantar             3
# 2         21.01     3.50  Masculino     Nao        Dom  Jantar             3
# 3         23.68     3.31  Masculino     Nao        Dom  Jantar             2
# 4         24.59     3.61   Feminino     Nao        Dom  Jantar             4
# ..          ...      ...        ...     ...        ...     ...           ...
# 239       29.03     5.92  Masculino     Nao        Sab  Jantar             3
# 240       27.18     2.00   Feminino     Sim        Sab  Jantar             2
# 241       22.67     2.00  Masculino     Sim        Sab  Jantar             2
# 242       17.82     1.75  Masculino     Nao        Sab  Jantar             2
# 243       18.78     3.00   Feminino     Nao        Sab  Jantar             2
#
# [244 rows x 7 columns]

# %%
sub_set_sexo_valorpago = sub_set.groupby('SEXO')['TOTAL PAGO'].sum()
sub_set_sexo_valorpago
#sub_set_sexo_valorpago = sub_set.groupby('SEXO').agg( TOTAL = ('TOTAL PAGO',np.sum) )
# Out:
# SEXO
# Feminino     1570.95
# Masculino    3256.82
# Name: TOTAL PAGO, dtype: float64

# %%
sub_set_sexo_valorpago.plot.bar(color='blue', ec='k')
plt.title('Valor Pago Por Sexo')
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Valor Pago', fontsize=12)
# Out:
# Text(0, 0.5, 'Valor Pago')

# %%
sub_set_sexo_valorpago.plot(kind='pie', autopct='%0.2f%%', colors=['blue','red'])
plt.title('Valor Pago Por Sexo')
# Out:
# Text(0.5, 1.0, 'Valor Pago Por Sexo')

# %%
sub_set_sexo_valorpago_fumante =(

  sub_set
  .groupby(by=['SEXO','FUMANTE'])['TOTAL PAGO']
  .sum()

)

sub_set_sexo_valorpago_fumante
# Out:
# SEXO       FUMANTE
# Feminino   Nao         977.68
#            Sim         593.27
# Masculino  Nao        1919.75
#            Sim        1337.07
# Name: TOTAL PAGO, dtype: float64

# %%
sub_set_sexo_valorpago_fumante.unstack().plot.bar(color=['blue','red'], ec='k')
plt.title('Valor Pago Por Sexo | Fumante')
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Valor Pago', fontsize=12)
#
# Out:
# Text(0, 0.5, 'Valor Pago')

# %%
sub_set_sexo_valorpago_fumante.unstack().plot.bar(color=['blue','red'], ec='k', stacked= True)
plt.title('Valor Pago Por Sexo | Fumante')
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Valor Pago', fontsize=12)
#
# Out:
# Text(0, 0.5, 'Valor Pago')

# %%
sub_set_sexo_valorpago_diasemana =(

  sub_set
  .groupby(by=['SEXO','DIA SEMANA'])
  .agg(
        TOTAL = ('TOTAL PAGO',np.sum)
      )
  .sort_values(by=['SEXO','DIA SEMANA'],ascending=[True,False])
)
sub_set_sexo_valorpago_diasemana
# Out:
# <ipython-input-179-86d6574f9460>:5: FutureWarning: The provided callable <function sum at 0x798c331abce0> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   .agg(
#                         TOTAL
# SEXO      DIA SEMANA
# Feminino  Sex          127.31
#           Sab         1085.94
#           Dom          357.70
# Masculino Sex          198.57
#           Sab         1788.79
#           Dom         1269.46

# %%
sub_set_sexo_valorpago_diasemana.plot(kind='bar',figsize=(20,5),ec='k')
plt.title('Valor Pago Por Sexo | Fumante')
plt.xlabel('Sexo', fontsize=12)
plt.ylabel('Valor Pago', fontsize=12)
#
# Out:
# Text(0, 0.5, 'Valor Pago')

# %%
#colunas_desejadas = ['PERIODO', 'TOTAL PAGO']
#df_selecionado = sub_set[colunas_desejadas]
df_selecionado = sub_set.groupby(by=['PERIODO'])['TOTAL PAGO'].sum()

df_selecionado
# Out:
# PERIODO
# Almoco    1167.47
# Jantar    3660.30
# Name: TOTAL PAGO, dtype: float64

# %%
df_selecionado.plot.barh(x='PERIODO', y='TOTAL PAGO',  color='red',ec='k')
plt.title('Total Pago Por Periodo')
plt.xlabel('Total Pago', fontsize=12)
plt.ylabel('Periodo', fontsize=12)
# Out:
# Text(0, 0.5, 'Periodo')

# %%
df_selecionado_SEXO = sub_set.groupby(by=['SEXO','PERIODO'])['TOTAL PAGO'].sum()


df_selecionado_SEXO
# Out:
# SEXO       PERIODO
# Feminino   Almoco      571.87
#            Jantar      999.08
# Masculino  Almoco      595.60
#            Jantar     2661.22
# Name: TOTAL PAGO, dtype: float64

# %%
df_selecionado_SEXO.plot.barh(x=['PERIODO,SEXO'], y='TOTAL PAGO',  color=['red','blue'],ec='k')
plt.title('Total Pago Por Sexo | Periodo')
plt.xlabel('Total Pago', fontsize=12)
plt.ylabel('Sexo | Periodo', fontsize=12)
# Out:
# Text(0, 0.5, 'Sexo | Periodo')
